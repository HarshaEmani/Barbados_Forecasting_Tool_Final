# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly.express as px

# %%
df_processed = pd.read_csv("df_processed.csv", index_col=0, parse_dates=["Timestamp"])
df_processed
# Out:
#                            Prev_Day_Net_Load_Demand  \
# Timestamp
# 2024-01-02 00:00:00+00:00                  0.505199
# 2024-01-02 01:00:00+00:00                  0.471730
# 2024-01-02 02:00:00+00:00                  0.457828
# 2024-01-02 03:00:00+00:00                  0.389528
# 2024-01-02 04:00:00+00:00                  0.343137
# ...                                             ...
# 2024-06-01 19:00:00+00:00                  1.135298
# 2024-06-01 20:00:00+00:00                  1.287603
# 2024-06-01 21:00:00+00:00                  1.264525
# 2024-06-01 22:00:00+00:00                  1.136287
# 2024-06-01 23:00:00+00:00                  1.041418
#
#                            Prev_Day_Temperature_Historic  \
# Timestamp
# 2024-01-02 00:00:00+00:00                      -1.431784
# 2024-01-02 01:00:00+00:00                      -1.504994
# 2024-01-02 02:00:00+00:00                      -1.456187
# 2024-01-02 03:00:00+00:00                      -1.602606
# ...

# %%
df_processed[['Prev_Day_Net_Load_Demand', 'Net_Load_Demand', 'Net_Load_Change']]
pd.DataFrame(df_processed['Net_Load_Demand'] - df_processed['Prev_Day_Net_Load_Demand'])
# Out:
#                                   0
# Timestamp
# 2024-01-02 00:00:00+00:00  0.080692
# 2024-01-02 01:00:00+00:00 -0.026574
# 2024-01-02 02:00:00+00:00 -0.104038
# 2024-01-02 03:00:00+00:00 -0.105266
# 2024-01-02 04:00:00+00:00 -0.084035
# ...                             ...
# 2024-06-01 19:00:00+00:00 -0.128462
# 2024-06-01 20:00:00+00:00 -0.083720
# 2024-06-01 21:00:00+00:00 -0.037939
# 2024-06-01 22:00:00+00:00 -0.004800
# 2024-06-01 23:00:00+00:00 -0.012404
#
# [3600 rows x 1 columns]
